# %% [markdown]
# # Foraging Robot Exercise
# In this individual exercise, you will write heuristics for a foraging robot so that it can efficiently gather fruits and berries in the forest. Your goal is to collect as much as you can!
#
# ## Learning goals
# Refresh your knowledge of semester 2 statistics:
# - Probability
# - Probability distributions
# - Conditional probabilities
#
# ## Overview
# As for all individual exercises, you are expected to complete the bronze level, but silver and gold levels are fully optional.
#
# Bronze Level (~1 hour)
# - Introduction to the scenario
# - Estimate distributions from samples
# - Calculate cumulative distribution functions
#
# Silver Level (~1 hour)
# - Conditional probabilities
#
# Gold Level (~2.5 hours)
# - Making a strategy

# %%
# Imports
from IPython.display import Image
import numpy as np
import seaborn as sns

from tests import tests

# %% [markdown]
# ## Bronze Level: Your foraging robot
#
# Congratulations on acquiring your own ForageBot 3000. This robot can autonomously collect fruits and berries from your local forest.
# Let's import and initialize our robot:

# %%
from scenario.forage_bot import ForageBot, Tree, BerryBush

forageBot = ForageBot()

# %% [markdown]
# In the step above, we import the ForageBot class from a different file (module). We then initialize an instance of this class as *forageBot*.
# You have probably used classes before, such as DataFrames from the pandas module. All the methods (functions) and attributes (variables) of ForageBot() will be explained when we first use them, but if you want to have a look, you can also check out the scenario file to see the class definition.
#
# The most important ability of your ForageBot, of course, is to forage. Every day, you can send out your robot to forage from one location.
# During our initital survey of your local forest, we identified two nearby apple trees. Let's send your new robot to one of these trees to collect apples.

# %%
tree_one = ForageBot.pre_survey['tree_one']

forageBot.forage(tree_one, verbose=True);
# Out:
# The robot collected 2.44kg of apples

# %% [markdown]
# Well done! You've collected your first apples.
# Now, try running the cell above a few more times. You will notice, that the amount of apples you collect changes every time. Even though you are collecting from the same tree, the yield for the day is random.
# Now, try collecting apples from the second tree a few times:

# %%
tree_two = ForageBot.pre_survey['tree_two']
#np.random.seed(42)
forageBot.forage(tree_two, verbose=True);
# Out:
# The robot collected 5.15kg of apples

# %% [markdown]
# Did you notice a difference?
# The second tree seems to usually yield more apples. However, it's sometimes possible to collect more apples from tree one than from tree two.
#
# Later, we will go explore the forest and find new trees. Of course, we would like to find the best trees which yield us the most apples.
# Given that the amount of apples for any day is random, we should try to find the __expected result__ from any given tree.
# The easiest way to do this, would be to estimate the __average__ amount of apples we collect from any tree.
# Try below to calculate the mean amount of apples collected from a tree.
# It's as simple as summing up all the values you collected, and then dividing by the number of samples that you collected.
#
# Complete the function below by filling in the '...'

# %%
def mean_tree_yield(tree, iterations=100) -> float:
    """ Collects from a tree multiple times, and then returns the mean yield.

    Args:
        tree: Reference to the tree which we forage (sample) from.
        iterations: The number of samples to collect.
    """
    # Create an empty list of samples
    samples = []
    # Collect one new sample from the given tree in each iteration using the forage() function of our bot.
    for i in range(iterations):
        samples.append(forageBot.forage(tree, verbose=True))
    # Calculate and return the mean
    total = 0.0
    for sample in samples:
        total += sample
    total /= iterations
    return total



mean_result = mean_tree_yield(tree_two)
print(f'After 100 iterations, the mean yield from this tree was: {mean_result:.02f}kg')

# This function is graded. You can uncomment the line below to test whether your function passes.
tests.Test_MeanTreeYield(mean_tree_yield);
# Out:
# The robot collected 3.44kg of apples
# The robot collected 5.42kg of apples
# The robot collected 4.26kg of apples
# The robot collected 4.68kg of apples
# The robot collected 6.27kg of apples
# The robot collected 4.89kg of apples
# The robot collected 5.23kg of apples
# The robot collected 6.59kg of apples
# The robot collected 3.69kg of apples
# The robot collected 5.21kg of apples
# The robot collected 3.93kg of apples
# The robot collected 4.12kg of apples
# The robot collected 5.66kg of apples
# The robot collected 5.36kg of apples
# The robot collected 4.19kg of apples
# The robot collected 2.15kg of apples
# The robot collected 3.23kg of apples
# The robot collected 5.03kg of apples
# The robot collected 4.57kg of apples
# The robot collected 4.38kg of apples
# The robot collected 5.19kg of apples
# The robot collected 4.26kg of apples
# The robot collected 6.16kg of apples
# The robot collected 5.80kg of apples
# The robot collected 4.13kg of apples
# The robot collected 5.13kg of apples
# The robot collected 4.67kg of apples
# The robot collected 4.50kg of apples
# The robot collected 5.14kg of apples
# The robot collected 3.96kg of apples
# The robot collected 2.97kg of apples
# The robot collected 4.95kg of apples
# The robot collected 5.87kg of apples
# The robot collected 4.85kg of apples
# The robot collected 6.57kg of apples
# The robot collected 4.47kg of apples
# The robot collected 5.22kg of apples
# The robot collected 4.37kg of apples
# The robot collected 4.32kg of apples
# The robot collected 5.61kg of apples
# The robot collected 5.18kg of apples
# The robot collected 4.88kg of apples
# The robot collected 5.23kg of apples
# The robot collected 5.82kg of apples
# The robot collected 5.02kg of apples
# The robot collected 6.09kg of apples
# The robot collected 3.12kg of apples
# The robot collected 3.43kg of apples
# The robot collected 4.62kg of apples
# The robot collected 3.59kg of apples
# The robot collected 2.72kg of apples
# The robot collected 5.78kg of apples
# The robot collected 5.22kg of apples
# The robot collected 5.72kg of apples
# The robot collected 4.58kg of apples
# The robot collected 5.14kg of apples
# The robot collected 4.53kg of apples
# The robot collected 6.27kg of apples
# The robot collected 5.28kg of apples
# The robot collected 5.83kg of apples
# The robot collected 4.97kg of apples
# The robot collected 5.69kg of apples
# The robot collected 5.74kg of apples
# The robot collected 4.04kg of apples
# The robot collected 3.36kg of apples
# The robot collected 5.12kg of apples
# The robot collected 2.85kg of apples
# The robot collected 5.79kg of apples
# The robot collected 5.29kg of apples
# The robot collected 5.32kg of apples
# The robot collected 4.03kg of apples
# The robot collected 5.32kg of apples
# The robot collected 6.65kg of apples
# The robot collected 3.74kg of apples
# The robot collected 4.66kg of apples
# The robot collected 5.58kg of apples
# The robot collected 4.98kg of apples
# The robot collected 5.00kg of apples
# The robot collected 3.90kg of apples
# The robot collected 3.42kg of apples
# The robot collected 3.74kg of apples
# The robot collected 5.13kg of apples
# The robot collected 5.28kg of apples
# The robot collected 6.24kg of apples
# The robot collected 6.15kg of apples
# The robot collected 5.84kg of apples
# The robot collected 4.60kg of apples
# The robot collected 3.19kg of apples
# The robot collected 5.39kg of apples
# The robot collected 5.82kg of apples
# The robot collected 4.10kg of apples
# The robot collected 5.21kg of apples
# The robot collected 4.42kg of apples
# The robot collected 3.90kg of apples
# The robot collected 3.91kg of apples
# The robot collected 5.16kg of apples
# The robot collected 4.74kg of apples
# The robot collected 5.68kg of apples
# The robot collected 4.59kg of apples
# The robot collected 5.82kg of apples
# After 100 iterations, the mean yield from this tree was: 4.83kg
# The robot collected 2.46kg of apples
# The robot collected 2.30kg of apples
# The robot collected 2.23kg of apples
# The robot collected 2.33kg of apples
# The robot collected 3.41kg of apples
# The robot collected 2.97kg of apples
# The robot collected 4.12kg of apples
# The robot collected 2.93kg of apples
# The robot collected 3.83kg of apples
# The robot collected 2.73kg of apples
# The robot collected 2.98kg of apples
# The robot collected 1.38kg of apples
# The robot collected 3.81kg of apples
# The robot collected 1.34kg of apples
# The robot collected 2.16kg of apples
# The robot collected 3.91kg of apples
# The robot collected 3.63kg of apples
# The robot collected 2.80kg of apples
# The robot collected 2.04kg of apples
# The robot collected 1.28kg of apples
# The robot collected 5.20kg of apples
# The robot collected 3.38kg of apples
# The robot collected 2.58kg of apples
# The robot collected 4.00kg of apples
# The robot collected 3.02kg of apples
# The robot collected 4.45kg of apples
# The robot collected 3.17kg of apples
# The robot collected 2.11kg of apples
# The robot collected 1.04kg of apples
# The robot collected 3.31kg of apples
# The robot collected 1.53kg of apples
# The robot collected 1.77kg of apples
# The robot collected 1.59kg of apples
# The robot collected 4.32kg of apples
# The robot collected 5.55kg of apples
# The robot collected 3.25kg of apples
# The robot collected 3.38kg of apples
# The robot collected 3.59kg of apples
# The robot collected 3.45kg of apples
# The robot collected 2.48kg of apples
# The robot collected 2.01kg of apples
# The robot collected 2.76kg of apples
# The robot collected 2.34kg of apples
# The robot collected 3.66kg of apples
# The robot collected 2.95kg of apples
# The robot collected 2.12kg of apples
# The robot collected 2.07kg of apples
# The robot collected 3.98kg of apples
# The robot collected 1.45kg of apples
# The robot collected 1.81kg of apples
# The robot collected 4.04kg of apples
# The robot collected 4.07kg of apples
# The robot collected 2.15kg of apples
# The robot collected 2.63kg of apples
# The robot collected 4.04kg of apples
# The robot collected 3.52kg of apples
# The robot collected 1.66kg of apples
# The robot collected 1.37kg of apples
# The robot collected 3.16kg of apples
# The robot collected 1.39kg of apples
# The robot collected 1.07kg of apples
# The robot collected 3.60kg of apples
# The robot collected 2.28kg of apples
# The robot collected 2.34kg of apples
# The robot collected 3.93kg of apples
# The robot collected 1.62kg of apples
# The robot collected 2.83kg of apples
# The robot collected 3.05kg of apples
# The robot collected 1.76kg of apples
# The robot collected 2.89kg of apples
# The robot collected 2.99kg of apples
# The robot collected 3.34kg of apples
# The robot collected 4.04kg of apples
# The robot collected 3.09kg of apples
# The robot collected 4.33kg of apples
# The robot collected 2.32kg of apples
# The robot collected 1.00kg of apples
# The robot collected 2.02kg of apples
# The robot collected 3.00kg of apples
# The robot collected 3.97kg of apples
# The robot collected 2.97kg of apples
# The robot collected 2.73kg of apples
# The robot collected 3.54kg of apples
# The robot collected 4.28kg of apples
# The robot collected 4.50kg of apples
# The robot collected 2.98kg of apples
# The robot collected 3.20kg of apples
# The robot collected 3.79kg of apples
# The robot collected 3.17kg of apples
# The robot collected 4.06kg of apples
# The robot collected 3.25kg of apples
# The robot collected 2.56kg of apples
# The robot collected 1.89kg of apples
# The robot collected 1.86kg of apples
# The robot collected 2.31kg of apples
# The robot collected 2.47kg of apples
# The robot collected 3.89kg of apples
# The robot collected 3.17kg of apples
# The robot collected 0.68kg of apples
# The robot collected 3.15kg of apples
# The robot collected 3.50kg of apples
# The robot collected 2.86kg of apples
# The robot collected 2.77kg of apples
# The robot collected 2.77kg of apples
# The robot collected 4.58kg of apples
# The robot collected 3.77kg of apples
# The robot collected 2.53kg of apples
# The robot collected 3.54kg of apples
# The robot collected 3.24kg of apples
# The robot collected 1.09kg of apples
# The robot collected 1.99kg of apples
# The robot collected 3.31kg of apples
# The robot collected 4.47kg of apples
# The robot collected 2.77kg of apples
# The robot collected 2.46kg of apples
# The robot collected 3.11kg of apples
# The robot collected 2.40kg of apples
# The robot collected 2.71kg of apples
# The robot collected 2.99kg of apples
# The robot collected 1.94kg of apples
# The robot collected 3.82kg of apples
# The robot collected 1.78kg of apples
# The robot collected 1.67kg of apples
# The robot collected 3.20kg of apples
# The robot collected 3.74kg of apples
# The robot collected 3.17kg of apples
# The robot collected 2.88kg of apples
# The robot collected 2.70kg of apples
# The robot collected 2.54kg of apples
# The robot collected 4.06kg of apples
# The robot collected 3.32kg of apples
# The robot collected 2.61kg of apples
# The robot collected 2.32kg of apples
# The robot collected 3.61kg of apples
# The robot collected 4.03kg of apples
# The robot collected 3.93kg of apples
# The robot collected 2.16kg of apples
# The robot collected 2.69kg of apples
# The robot collected 2.52kg of apples
# The robot collected 2.81kg of apples
# The robot collected 3.81kg of apples
# The robot collected 4.36kg of apples
# The robot collected 3.36kg of apples
# The robot collected 2.35kg of apples
# The robot collected 2.96kg of apples
# The robot collected 4.56kg of apples
# The robot collected 3.09kg of apples
# The robot collected 2.70kg of apples
# The robot collected 2.78kg of apples
# The robot collected 3.36kg of apples
# The robot collected 2.19kg of apples
# The robot collected 2.50kg of apples
# The robot collected 3.92kg of apples
# The robot collected 3.33kg of apples
# The robot collected 3.10kg of apples
# The robot collected 3.97kg of apples
# The robot collected 2.30kg of apples
# The robot collected 2.67kg of apples
# The robot collected 3.30kg of apples
# The robot collected 3.26kg of apples
# The robot collected 1.58kg of apples
# The robot collected 2.58kg of apples
# The robot collected 2.84kg of apples
# The robot collected 3.40kg of apples
# The robot collected 3.26kg of apples
# The robot collected 2.93kg of apples
# The robot collected 1.08kg of apples
# The robot collected 2.97kg of apples
# The robot collected 3.06kg of apples
# The robot collected 5.46kg of apples
# The robot collected 2.81kg of apples
# The robot collected 3.30kg of apples
# The robot collected 4.14kg of apples
# The robot collected 3.75kg of apples
# The robot collected 4.40kg of apples
# The robot collected 1.60kg of apples
# The robot collected 2.01kg of apples
# The robot collected 2.43kg of apples
# The robot collected 1.45kg of apples
# The robot collected 3.07kg of apples
# The robot collected 2.08kg of apples
# The robot collected 4.55kg of apples
# The robot collected 2.22kg of apples
# The robot collected 2.68kg of apples
# The robot collected 3.81kg of apples
# The robot collected 1.77kg of apples
# The robot collected 1.39kg of apples
# The robot collected 3.18kg of apples
# The robot collected 3.26kg of apples
# The robot collected 3.78kg of apples
# The robot collected 3.52kg of apples
# The robot collected 3.30kg of apples
# The robot collected 2.32kg of apples
# The robot collected 3.23kg of apples
# The robot collected 3.29kg of apples
# The robot collected 2.29kg of apples
# The robot collected 4.87kg of apples
# The robot collected 3.47kg of apples
# The robot collected 2.03kg of apples
# The robot collected 3.79kg of apples
# The robot collected 5.50kg of apples
# The robot collected 4.86kg of apples
# The robot collected 4.77kg of apples
# The robot collected 4.77kg of apples
# The robot collected 6.58kg of apples
# The robot collected 5.77kg of apples
# The robot collected 4.53kg of apples
# The robot collected 5.54kg of apples
# The robot collected 5.24kg of apples
# The robot collected 3.09kg of apples
# The robot collected 3.99kg of apples
# The robot collected 5.31kg of apples
# The robot collected 6.47kg of apples
# The robot collected 4.77kg of apples
# The robot collected 4.46kg of apples
# The robot collected 5.11kg of apples
# The robot collected 4.40kg of apples
# The robot collected 4.71kg of apples
# The robot collected 4.99kg of apples
# The robot collected 3.94kg of apples
# The robot collected 5.82kg of apples
# The robot collected 3.78kg of apples
# The robot collected 3.67kg of apples
# The robot collected 5.20kg of apples
# The robot collected 5.74kg of apples
# The robot collected 5.17kg of apples
# The robot collected 4.88kg of apples
# The robot collected 4.70kg of apples
# The robot collected 4.54kg of apples
# The robot collected 6.06kg of apples
# The robot collected 5.32kg of apples
# The robot collected 4.61kg of apples
# The robot collected 4.32kg of apples
# The robot collected 5.61kg of apples
# The robot collected 6.03kg of apples
# The robot collected 5.93kg of apples
# The robot collected 4.16kg of apples
# The robot collected 4.69kg of apples
# The robot collected 4.52kg of apples
# The robot collected 4.81kg of apples
# The robot collected 5.81kg of apples
# The robot collected 6.36kg of apples
# The robot collected 5.36kg of apples
# The robot collected 4.35kg of apples
# The robot collected 4.96kg of apples
# The robot collected 6.56kg of apples
# The robot collected 5.09kg of apples
# The robot collected 4.70kg of apples
# The robot collected 4.78kg of apples
# The robot collected 5.36kg of apples
# The robot collected 4.19kg of apples
# The robot collected 4.50kg of apples
# The robot collected 5.92kg of apples
# The robot collected 5.33kg of apples
# The robot collected 5.10kg of apples
# The robot collected 5.97kg of apples
# The robot collected 4.30kg of apples
# The robot collected 4.67kg of apples
# The robot collected 5.30kg of apples
# The robot collected 5.26kg of apples
# The robot collected 3.58kg of apples
# The robot collected 4.58kg of apples
# The robot collected 4.84kg of apples
# The robot collected 5.40kg of apples
# The robot collected 5.26kg of apples
# The robot collected 4.93kg of apples
# The robot collected 3.08kg of apples
# The robot collected 4.97kg of apples
# The robot collected 5.06kg of apples
# The robot collected 7.46kg of apples
# The robot collected 4.81kg of apples
# The robot collected 5.30kg of apples
# The robot collected 6.14kg of apples
# The robot collected 5.75kg of apples
# The robot collected 6.40kg of apples
# The robot collected 3.60kg of apples
# The robot collected 4.01kg of apples
# The robot collected 4.43kg of apples
# The robot collected 3.45kg of apples
# The robot collected 5.07kg of apples
# The robot collected 4.08kg of apples
# The robot collected 6.55kg of apples
# The robot collected 4.22kg of apples
# The robot collected 4.68kg of apples
# The robot collected 5.81kg of apples
# The robot collected 3.77kg of apples
# The robot collected 3.39kg of apples
# The robot collected 5.18kg of apples
# The robot collected 5.26kg of apples
# The robot collected 5.78kg of apples
# The robot collected 5.52kg of apples
# The robot collected 5.30kg of apples
# The robot collected 4.32kg of apples
# The robot collected 5.23kg of apples
# The robot collected 5.29kg of apples
# The robot collected 4.29kg of apples
# The robot collected 6.87kg of apples
# The robot collected 5.47kg of apples
# The robot collected 4.03kg of apples
# The robot collected 5.79kg of apples
# The robot collected 68.96kg of apples
# The robot collected 61.34kg of apples
# The robot collected 60.19kg of apples
# The robot collected 60.19kg of apples
# The robot collected 81.95kg of apples
# The robot collected 72.21kg of apples
# The robot collected 57.37kg of apples
# The robot collected 69.51kg of apples
# The robot collected 65.90kg of apples
# The robot collected 40.04kg of apples
# The robot collected 50.85kg of apples
# The robot collected 66.77kg of apples
# The robot collected 80.59kg of apples
# The robot collected 60.29kg of apples
# The robot collected 56.47kg of apples
# The robot collected 64.33kg of apples
# The robot collected 55.79kg of apples
# The robot collected 59.50kg of apples
# The robot collected 62.84kg of apples
# The robot collected 50.31kg of apples
# The robot collected 72.87kg of apples
# The robot collected 48.35kg of apples
# The robot collected 47.06kg of apples
# The robot collected 65.36kg of apples
# The robot collected 71.86kg of apples
# The robot collected 65.06kg of apples
# The robot collected 61.61kg of apples
# The robot collected 59.39kg of apples
# The robot collected 57.47kg of apples
# The robot collected 75.69kg of apples
# The robot collected 66.89kg of apples
# The robot collected 58.38kg of apples
# The robot collected 54.88kg of apples
# The robot collected 70.34kg of apples
# The robot collected 75.37kg of apples
# The robot collected 74.18kg of apples
# The robot collected 52.93kg of apples
# The robot collected 59.29kg of apples
# The robot collected 57.25kg of apples
# The robot collected 60.77kg of apples
# The robot collected 72.75kg of apples
# The robot collected 79.27kg of apples
# The robot collected 67.34kg of apples
# The robot collected 55.26kg of apples
# The robot collected 62.57kg of apples
# The robot collected 81.78kg of apples
# The robot collected 64.04kg of apples
# The robot collected 59.41kg of apples
# The robot collected 60.36kg of apples
# The robot collected 67.29kg of apples
# The robot collected 53.30kg of apples
# The robot collected 56.98kg of apples
# The robot collected 73.98kg of apples
# The robot collected 66.95kg of apples
# The robot collected 64.16kg of apples
# The robot collected 74.62kg of apples
# The robot collected 54.58kg of apples
# The robot collected 59.07kg of apples
# The robot collected 66.55kg of apples
# The robot collected 66.13kg of apples
# The robot collected 46.02kg of apples
# The robot collected 57.95kg of apples
# The robot collected 61.06kg of apples
# The robot collected 67.85kg of apples
# The robot collected 66.09kg of apples
# The robot collected 62.11kg of apples
# The robot collected 39.97kg of apples
# The robot collected 62.68kg of apples
# The robot collected 63.72kg of apples
# The robot collected 92.56kg of apples
# The robot collected 60.69kg of apples
# The robot collected 66.62kg of apples
# The robot collected 76.71kg of apples
# The robot collected 72.02kg of apples
# The robot collected 79.83kg of apples
# The robot collected 46.18kg of apples
# The robot collected 51.11kg of apples
# The robot collected 56.20kg of apples
# The robot collected 44.39kg of apples
# The robot collected 63.82kg of apples
# The robot collected 51.97kg of apples
# The robot collected 81.60kg of apples
# The robot collected 53.60kg of apples
# The robot collected 59.14kg of apples
# The robot collected 72.76kg of apples
# The robot collected 48.23kg of apples
# The robot collected 43.71kg of apples
# The robot collected 65.22kg of apples
# The robot collected 66.12kg of apples
# The robot collected 72.38kg of apples
# The robot collected 69.26kg of apples
# The robot collected 66.56kg of apples
# The robot collected 54.84kg of apples
# The robot collected 65.79kg of apples
# The robot collected 66.52kg of apples
# The robot collected 54.43kg of apples
# The robot collected 85.39kg of apples
# The robot collected 68.69kg of apples
# The robot collected 51.30kg of apples
# The robot collected 72.45kg of apples
# The robot collected 430.06kg of apples
# The robot collected 152.58kg of apples
# The robot collected 110.67kg of apples
# The robot collected 110.68kg of apples
# The robot collected 903.12kg of apples
# The robot collected 548.37kg of apples
# The robot collected 7.84kg of apples
# The robot collected 450.10kg of apples
# The robot collected 318.74kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 350.33kg of apples
# The robot collected 853.49kg of apples
# The robot collected 114.34kg of apples
# The robot collected 0.00kg of apples
# The robot collected 261.47kg of apples
# The robot collected 0.00kg of apples
# The robot collected 85.53kg of apples
# The robot collected 207.10kg of apples
# The robot collected 0.00kg of apples
# The robot collected 572.45kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 299.03kg of apples
# The robot collected 535.71kg of apples
# The robot collected 287.89kg of apples
# The robot collected 162.46kg of apples
# The robot collected 81.42kg of apples
# The robot collected 11.70kg of apples
# The robot collected 674.96kg of apples
# The robot collected 354.62kg of apples
# The robot collected 44.72kg of apples
# The robot collected 0.00kg of apples
# The robot collected 480.30kg of apples
# The robot collected 663.55kg of apples
# The robot collected 619.97kg of apples
# The robot collected 0.00kg of apples
# The robot collected 77.87kg of apples
# The robot collected 3.60kg of apples
# The robot collected 131.87kg of apples
# The robot collected 568.07kg of apples
# The robot collected 805.68kg of apples
# The robot collected 371.03kg of apples
# The robot collected 0.00kg of apples
# The robot collected 197.34kg of apples
# The robot collected 896.75kg of apples
# The robot collected 251.04kg of apples
# The robot collected 82.33kg of apples
# The robot collected 117.00kg of apples
# The robot collected 369.06kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 613.03kg of apples
# The robot collected 356.66kg of apples
# The robot collected 255.42kg of apples
# The robot collected 636.30kg of apples
# The robot collected 0.00kg of apples
# The robot collected 69.81kg of apples
# The robot collected 342.40kg of apples
# The robot collected 327.08kg of apples
# The robot collected 0.00kg of apples
# The robot collected 29.18kg of apples
# The robot collected 142.52kg of apples
# The robot collected 389.57kg of apples
# The robot collected 325.55kg of apples
# The robot collected 180.47kg of apples
# The robot collected 0.00kg of apples
# The robot collected 201.41kg of apples
# The robot collected 239.32kg of apples
# The robot collected 1289.44kg of apples
# The robot collected 128.94kg of apples
# The robot collected 344.78kg of apples
# The robot collected 712.41kg of apples
# The robot collected 541.59kg of apples
# The robot collected 826.02kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 242.96kg of apples
# The robot collected 0.00kg of apples
# The robot collected 890.32kg of apples
# The robot collected 0.00kg of apples
# The robot collected 72.26kg of apples
# The robot collected 568.51kg of apples
# The robot collected 0.00kg of apples
# The robot collected 0.00kg of apples
# The robot collected 293.68kg of apples
# The robot collected 326.57kg of apples
# The robot collected 554.66kg of apples
# The robot collected 441.09kg of apples
# The robot collected 342.78kg of apples
# The robot collected 0.00kg of apples
# The robot collected 314.49kg of apples
# The robot collected 341.07kg of apples
# The robot collected 0.00kg of apples
# The robot collected 1028.34kg of apples
# The robot collected 420.06kg of apples
# The robot collected 0.00kg of apples
# The robot collected 556.96kg of apples
# All tests passed

# %% [markdown]
# If you rerun the cell above, you will notice that the mean yield still changes every time, since we are only estimating it from 100 samples. Nevertheless, our estimate is now much more consistent than any single sample was.
#
# While the mean is often a useful metric, we might get an even better idea of what each apple tree yields if we plot the distribution of apples. Complete the code below to do just that.

# %%
def plot_distribution(samples, color='blue') -> None:
    """ Plots the distribution of collected samples.

    Args:
        samples: A list of samples from a distribution.
        color: Name of the color in which to draw the distribution
    """

    # Hint: Use the histplot function of seaborn (imported as sns)
    sns.histplot(samples, color=color, bins=24)
    return None

# Set random seed so output matches the expected output
np.random.seed(42)
# Collect from a tree 500 times
samples = [forageBot.forage(tree_two) for i in range(500)]

plot_distribution(samples)

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot1.png" alt="Distribution plot for tree_two" width="200"/>
#
# Now let's compare the two trees:

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples_one = [forageBot.forage(tree_one) for i in range(500)]
samples_two = [forageBot.forage(tree_two) for i in range(500)]

# Plot distributions
plot_distribution(samples_one, color='blue')
plot_distribution(samples_two, color='red')

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot2.png" alt="Distribution plot for tree_two" width="200"/>
#
# You can see that the distributions from both apple trees have a similar shape, but that tree two tends to give more apples than tree one.
#
# Now, let's have a look at two more trees

# %%
tree_three = ForageBot.pre_survey['tree_three']
tree_four = ForageBot.pre_survey['tree_four']

# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples_three = [forageBot.forage(tree_three) for i in range(500)]
samples_four = [forageBot.forage(tree_four) for i in range(500)]

# Plot distributions
plot_distribution(samples_three, color='blue')
plot_distribution(samples_four, color='red')

# %% [markdown]
# Although both of these apple trees seem to also be normally distributed, tree three has a much higher variance.
#
# If you run our mean_tree_yield() function, you will find that tree three (blue distribution) has a higher mean yield.
#
# But let's say you need 5kg of apples today. Can you calculate which of the two trees (tree_three and tree_four) is most likely to yield you at least 5kg on any given day?
#
# Don't remember how to calculate a probability from a distribution? Check out this: https://mathworld.wolfram.com/DistributionFunction.html
#
# You will need to do two things:
# 1) Estimate the parameters of the distribution for each tree from the samples you collected. (You can use scipy.stats.norm)
# 2) Calculate the probability for each tree to yield at least 5kg (You will want to use the cumulative distribution function for this)
#
# The commonly used Python packages all have pretty decent online documentation. Don't intrinsically know how to use scipy.stats.norm? Nobody does. Check this:
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.norm.html

# %%
from scipy.stats import norm

# Use the same samples we collected above to make sure your answer matches ours.
np.random.seed(42)
samples_three = [forageBot.forage(tree_three) for i in range(500)]
samples_four = [forageBot.forage(tree_four) for i in range(500)]

# Complete the two steps described above here
tree_three_mean = np.mean(samples_three)
tree_four_mean = np.mean(samples_four)

tree_three_std = np.std(samples_three)
tree_four_std = np.std(samples_four)

# Assign the probability that tree three yields more than 5kg of apples on any given day to ANSWER_PROB_TREE_THREE
ANSWER_PROB_TREE_THREE = norm.cdf(5, loc=tree_three_mean, scale=tree_three_std)
# Assign the probability that tree four yields more than 5kg of apples on any given day to ANSWER_PROB_TREE_FOUR
ANSWER_PROB_TREE_FOUR = norm.cdf(5, loc=tree_four_mean, scale=tree_four_std)


tests.Test_ExerciseTwo(ANSWER_PROB_TREE_THREE=ANSWER_PROB_TREE_THREE, ANSWER_PROB_TREE_FOUR=ANSWER_PROB_TREE_FOUR);
# Out:
# All tests passed

# %% [markdown]
# Now that we have figured out how to evaluate trees, let's explore a little and find some new ones.
# Your forage bot can also explore to find new foragable things in the forest. Run the function explore() a few times and see what you get.

# %%
discovery = forageBot.explore()
print(type(discovery))
# Out:
# <class 'scenario.forage_bot.BerryBush'>

# %% [markdown]
# The output you get might not be the most clear. <scenario.forage_bot.Tree object at 0x000002978E34B7D0> simply means that the function explore() returned an object of class Tree from the scenario.forage_bot module. <scenario.forage_bot.BerryBush object at 0x000001ECEFC7B040> is a different class, BerryBush, from the same module. Apparently, explore can return one of two different return types.
#
# So, as you can see, your robot will find new trees and berry bushes when exploring.

# %% [markdown]
# ## Final task bronze level
# Your final task for the bronze medal is to find a tree that will yield more than 8kg of apples on more than 75% of days.
# Use the explore function together with the functions you have created so far!
#
# Note: Trees have some attributes which of course you could theoretically look up directly by checking the scenario files, instead of estimating them from samples. But a solution which is based on this will NOT be accepted.
#
# Since the explore() method can result in both Tree or BerryBush, you will need to check whether you found a Tree. There are several ways in which this can be done, on of which is the built-in isinstance() function.

# %%
# Set a seed so that your solution works when we test it.
np.random.seed(42)

# Search for a new tree that fulfils the requirement
found_tree = False

while not found_tree:
    new_discovery = forageBot.explore()
    if str(type(new_discovery)) == "<class 'scenario.forage_bot.Tree'>":
        samples = [forageBot.forage(new_discovery) for i in range(500)]
        discovery_mean = np.mean(samples)
        discovery_std = np.std(samples)
        
        probability = norm.cdf(8, loc=discovery_mean, scale=discovery_std)
        if probability >= 0.75:
            found_tree = True

# Assign this tree here
BRONZE_MEDAL_TREE = new_discovery

tests.Test_ExerciseThree(BRONZE_MEDAL_TREE=BRONZE_MEDAL_TREE);
# Out:
# All tests passed

# %% [markdown]
# ## Silver Level: Conditional Probabilities
# When solving the last task, you found not just trees, but also bushes. You had to ignore them while looking for a suitable tree, but now let's have a look at a berry bush!
# Run the cell below a few times.

# %%
bush_one = forageBot.pre_survey['bush_one']
forageBot.forage(bush_one, verbose=True);
# Out:
# The robot collected 1.99kg of berries

# %% [markdown]
# Just like the apple trees, the yield varies each day; however, for berries, the yield seems to vary even more strongly.
#
# Let's collect a few samples and then plot the distribution.

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

# Collect from both trees
samples = [forageBot.forage(bush_one) for i in range(5000)]

# Plot distributions
plot_distribution(samples)

# %% [markdown]
# That looks quite different from the apple trees!
#
# This appears to be a bimodal distribution. A common reason for bimodal distributions is that we might be measuring two different populations as one, or that our samples might be affected by a variable that we are not teking into account.
#
# Let's see if we can find an underlying explanation for this shape. One thing that might affect the performance of your ForageBot might be the weather. Let's try plotting samples from this berry bush depending on the current weather.
#
# You can check whether it is currently sunny or raining with forageBot.is_it_raining()
#
# Note that weather changes IMMEDIATELY AFTER each forage() or explore() action (or, strictly speaking, changes at the end of that function call). That means you must check the weather first, then go forage().

# %%
# Set random seed so output matches the expected output
np.random.seed(42)

samples_sunny = []
samples_rainy = []

for i in range(5000):
    # Write code here to fill the lists above with a total of 5000 samples
    if forageBot.is_it_raining() == False:
        samples_sunny.append(forageBot.forage(bush_one))
    else:
        samples_rainy.append(forageBot.forage(bush_one))




# Plot distributions
plot_distribution(samples_sunny, color='blue')
plot_distribution(samples_rainy, color='red')

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot3.png" alt="Seperate distributions based on weather" width="200"/>
#
# This indeed looks like two separate distributions! Make sure to note whether your ForageBot collects more berries in sunny or rainy weather, it may come in handy later!
#
# Earlier, we tried to figure out which apple tree gives us the best chance of getting a certain amount of apples for making pie. Now it's time for a blueberry cobbler, so let's see if we can calculate the chance of collecting at least 2kg of berries. Let us first plot the CDF of these samples by running the cell below.

# %%
# Collecting again just as above
np.random.seed(42)
samples = [forageBot.forage(bush_one) for i in range(5000)]

# Generate the cumulative distribution function from our samples
sorted_samples = np.sort(samples)
probability = np.arange(len(samples)) / (len(samples) - 1)

# Plot the CDF:
sns.lineplot(x=sorted_samples, y=probability);

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot4.png" alt="" width="200"/>
#
# This plot shows us that there is visually a roughly 40% chance of getting a value below 2 from this distribution and thus a roughly 60% chance of getting at 2kg of berries or more.
#
# But we can get an even better estimate, if we take take the weather into account! Try creating the same plot, but split by weather.

# %%
# Collecting again just as above
np.random.seed(42)

# These samples should still be available, if not recollect them as above.
# samples_sunny = []
# samples_rainy = []

# Calculate the 2 PDFs for sunny and rainy weather here, using the code above.
probability_sunny = np.arange(len(samples_sunny)) / (len(samples_sunny) - 1)
probability_rainy = np.arange(len(samples_rainy)) / (len(samples_rainy) - 1)

sorted_samples_sunny = np.sort(samples_sunny)
sorted_samples_rainy = np.sort(samples_rainy)

# Plot the CDF:
sns.lineplot(x=sorted_samples_sunny, y=probability_sunny, color='blue')
sns.lineplot(x=sorted_samples_rainy, y=probability_rainy, color='red');

# %% [markdown]
# You should generate this image:
#
# <img src="resources/plot5.png" alt="" width="200"/>
#
# Looks like you are almost guaranteed 2kg of berries on a sunny day, but that on a rainy day you will rarely find so many.
#
# But if we want to plan ahead for whether we can bake a blueberry cobbler this week, we also need to know the probability of rain!
#
# We could collect some samples and then estimate the probability of rain, but I can also just tell you: Any day has a 40% chance of rain and is otherwise sunny.
#
# Now, with these probabilities, we can even make inferences on what the weather was like just from the amount of berries we collected. Let's say you programmed your BakeBot (sold separately) to make a blueberry cobbler any time the ForageBot returns with at least 2kg of berries. You've just come back from vacation, and there is a cobbler made yesterday waiting for you in the kitchen. What are the odds that it was raining yesterday?
#
# You know that $P(rain)=0.4$
# Now calculate the probability to find a cobbler depending on whether or not it rained, that is $P(cobbler|sunny)$ and $P(cobbler|rainy)$

# %%
# Here are the precise distributions for bush_one:
bush_one_sunny_dist = norm(loc=3, scale=0.5)
bush_one_rainy_dist = norm(loc=1.5, scale=0.5)

# Calculate the precise probability of getting at least 2kg of berries from bush_one given either weather (using the cdf)

ANSWER_PROB_IF_SUNNY = bush_one_sunny_dist.cdf(2)
ANSWER_PROB_IF_RAINY = bush_one_rainy_dist.cdf(2)

# %% [markdown]
# Now calculate the probability that it has rained, given that you know enough berries have been collected, that is $P(rainy|cobbler)$
#
# You can use Bayes' rule: $$P(B|A)={\frac {P(A|B)*P(B)}{P(A)}}$$
#
# Remember that the overall probability of event A can be rewritten as: $$P(A)={P(A|B)P(B) + P(A|\neg B)P(\neg B)}$$
#
# Hint: If you are lost, try entering what you know here: https://www.omnicalculator.com/statistics/conditional-probability

# %%
# Calculate the probability that it has rained
"""def has_it_rained() -> bool:
    cobbler_rainy_probability = 1 - (0.4 * ANSWER_PROB_IF_RAINY / (0.6 * ANSWER_PROB_IF_SUNNY + 0.4 * ANSWER_PROB_IF_RAINY))
    return cobbler_rainy_probability >= 0.5"""

# Assign the probability that it has rained below
ANSWER_HAS_IT_RAINED = 1 - (0.4 * ANSWER_PROB_IF_RAINY / (0.6 * ANSWER_PROB_IF_SUNNY + 0.4 * ANSWER_PROB_IF_RAINY))

# %% [markdown]
# ## Gold Level: Explore and Exploit
# The gold level is a single challenge: Make as much money from your ForageBot as possible in 5000 days.
#
# There are a few new rules for this, which will be briefoly explained.
#
# First, every time to explore or forage a day passes, which will be counted. The days can be reset with ForageBot.reset_days() which you MUST call in the first AND ONLY THE FIRST line of your solution.

# %%
ForageBot.reset_days()
forageBot = ForageBot()
day = forageBot.what_day_is_it()
print(f'It is day {day}')
forageBot.explore()
day = forageBot.what_day_is_it()
print(f'It is day {day}')
forageBot.forage(ForageBot.pre_survey['tree_one'])
day = forageBot.what_day_is_it()
print(f'It is day {day}')
# Out:
# It is day 0
# It is day 1
# It is day 2

# %% [markdown]
# Things you forage are stored in your inventory. Apples and berries last three days and then expire (disappear from the inventory).
# Items in the inventory are stored as tuples: (Type of fruit: str, amount: float, days until it spoils: int)

# %%
forageBot = ForageBot()
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['tree_one'])
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['tree_one'])
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['bush_one'])
print(forageBot.inventory)
forageBot.forage(ForageBot.pre_survey['bush_one'])
print(forageBot.inventory)
# Out:
# []
# [('apples', 5.141658432216612, 3)]
# [('apples', 5.141658432216612, 2), ('apples', 2.1147696543084056, 3)]
# [('apples', 5.141658432216612, 1), ('apples', 2.1147696543084056, 2), ('berries', 2.7939057597639247, 3)]
# [('apples', 2.1147696543084056, 1), ('berries', 2.7939057597639247, 2), ('berries', 1.616547619529872, 3)]

# %% [markdown]
# You can now sell what you foraged! You can only sell all of your inventory at once, not individual items.
# Apples are usually worth 1 euro per kilo.
# Berries are usually worth 3 euros per kilo.
# Prices can however vary by weekday. Apples sell better on Tuesday and Wednesday. Berries sell better on the weekend. The first day is a Monday.

# %%
forageBot = ForageBot()
forageBot.forage(ForageBot.pre_survey['tree_one'])
forageBot.sell(verbose=True)
forageBot.forage(ForageBot.pre_survey['tree_one'])
forageBot.forage(ForageBot.pre_survey['bush_one'])
forageBot.sell(verbose=True);
# Out:
# You earned €3.12 from selling your inventory. Your total is now €3.12
# You earned €24.66 from selling your inventory. Your total is now €27.78

# %% [markdown]
# Now try to find the optimal strategy for making as much money in 5000 days as possible!
#
# - You may call forageBot.explore() and forageBot.forage() a combined total of 5000 times. Weather can change every day, and the day passes immediately after exploring or foraging.
# - You may sell() as often as you want. Take weekday prices into account. The first day is Monday.
# - ForageBot.reset_days() MUST be called in the first AND ONLY THE FIRST line of your solution.
# - You MAY NOT use any of the pre_survey trees and bushes, nor may you use trees or bushes you have discovered previously. You can only forage things you have found within the 5000 days.
# - You MAY NOT directly modify any things you can find in forage_bot.py, such as manually creating trees or messing with sales prices, etc.
# - You MAY NOT use additional imports in the solution you submit. You may use libraries imported at the beginning, such as numpy.
# - You may hardcode parameters that you may have discovered while using additional libraries such as sklearn, as long as those are no longer imported and required for the solution.
# - We may test your solution with a different random seed if the solution seems to rely on something that can only happen in the chosen seed. In that case, you will receive gold if your solution passes at least a quarter of all seeds.
#
# You will receive the gold medal if you manage to earn more than €100.000,00!

# %% [markdown]
# # *I don't have enough time to work this out, but I will definitely look back on this in my freetime. It is a fun challenge.*

# %%
ForageBot.reset_days(limit=5000)
forageBot = ForageBot()
np.random.seed(42)
# Do not change the lines above

# Do whatever you think is best! You can call explore() and forage() a combined total of 5000 times, and should then stop. Don't forget to sell() as well.
# Here is a sample solution, which you can hopefully improve:



worth_to_sell = False

sell_counter = 2
sell_counter_active = False

x = 0

week = ('Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday')
day_counter = 0
day = week[day_counter]

for i in range(4999):
    new_discovery = forageBot.explore()
    
    # Get day name
    if i % 7 == 0:
        day_counter = 0
        day = week[day_counter]
    else:
        day_counter += 1
        day = week[day_counter]

    loot = forageBot.forage(new_discovery)

    if str(type(loot)) == "<class 'scenario.forage_bot.Tree'>":
        if day == 'Sunday' or day == 'Monday':
            worth_to_sell = True
            sell_counter_active = True
    elif str(type(loot)) == "<class 'scenario.forage_bot.berryBush'>":
        if day == 'Thursday' or day == 'Friday':
            worth_to_sell = True 
            sell_counter_active = True    
    else:
        worth_to_sell = False
    
    if sell_counter_active:
        sell_counter -= 1
        if sell_counter < 0:
            forageBot.sell(verbose=True)
            sell_counter = 2
            sell_counter_active = False
            x += 1
# Out:
# 5000 days have passed! Your final score is €0.00. Your script should stop here.
# 5001 days have passed! Your final score is €0.00. Your script should stop here.
# 5002 days have passed! Your final score is €0.00. Your script should stop here.
# 5003 days have passed! Your final score is €0.00. Your script should stop here.
# 5004 days have passed! Your final score is €0.00. Your script should stop here.
# 5005 days have passed! Your final score is €0.00. Your script should stop here.
# 5006 days have passed! Your final score is €0.00. Your script should stop here.
# 5007 days have passed! Your final score is €0.00. Your script should stop here.
# 5008 days have passed! Your final score is €0.00. Your script should stop here.
# 5009 days have passed! Your final score is €0.00. Your script should stop here.
# 5010 days have passed! Your final score is €0.00. Your script should stop here.
# 5011 days have passed! Your final score is €0.00. Your script should stop here.
# 5012 days have passed! Your final score is €0.00. Your script should stop here.
# 5013 days have passed! Your final score is €0.00. Your script should stop here.
# 5014 days have passed! Your final score is €0.00. Your script should stop here.
# 5015 days have passed! Your final score is €0.00. Your script should stop here.
# 5016 days have passed! Your final score is €0.00. Your script should stop here.
# 5017 days have passed! Your final score is €0.00. Your script should stop here.
# 5018 days have passed! Your final score is €0.00. Your script should stop here.
# 5019 days have passed! Your final score is €0.00. Your script should stop here.
# 5020 days have passed! Your final score is €0.00. Your script should stop here.
# 5021 days have passed! Your final score is €0.00. Your script should stop here.
# 5022 days have passed! Your final score is €0.00. Your script should stop here.
# 5023 days have passed! Your final score is €0.00. Your script should stop here.
# 5024 days have passed! Your final score is €0.00. Your script should stop here.
# 5025 days have passed! Your final score is €0.00. Your script should stop here.
# 5026 days have passed! Your final score is €0.00. Your script should stop here.
# 5027 days have passed! Your final score is €0.00. Your script should stop here.
# 5028 days have passed! Your final score is €0.00. Your script should stop here.
# 5029 days have passed! Your final score is €0.00. Your script should stop here.
# 5030 days have passed! Your final score is €0.00. Your script should stop here.
# 5031 days have passed! Your final score is €0.00. Your script should stop here.
# 5032 days have passed! Your final score is €0.00. Your script should stop here.
# 5033 days have passed! Your final score is €0.00. Your script should stop here.
# 5034 days have passed! Your final score is €0.00. Your script should stop here.
# 5035 days have passed! Your final score is €0.00. Your script should stop here.
# 5036 days have passed! Your final score is €0.00. Your script should stop here.
# 5037 days have passed! Your final score is €0.00. Your script should stop here.
# 5038 days have passed! Your final score is €0.00. Your script should stop here.
# 5039 days have passed! Your final score is €0.00. Your script should stop here.
# 5040 days have passed! Your final score is €0.00. Your script should stop here.
# 5041 days have passed! Your final score is €0.00. Your script should stop here.
# 5042 days have passed! Your final score is €0.00. Your script should stop here.
# 5043 days have passed! Your final score is €0.00. Your script should stop here.
# 5044 days have passed! Your final score is €0.00. Your script should stop here.
# 5045 days have passed! Your final score is €0.00. Your script should stop here.
# 5046 days have passed! Your final score is €0.00. Your script should stop here.
# 5047 days have passed! Your final score is €0.00. Your script should stop here.
# 5048 days have passed! Your final score is €0.00. Your script should stop here.
# 5049 days have passed! Your final score is €0.00. Your script should stop here.
# 5050 days have passed! Your final score is €0.00. Your script should stop here.
# 5051 days have passed! Your final score is €0.00. Your script should stop here.
# 5052 days have passed! Your final score is €0.00. Your script should stop here.
# 5053 days have passed! Your final score is €0.00. Your script should stop here.
# 5054 days have passed! Your final score is €0.00. Your script should stop here.
# 5055 days have passed! Your final score is €0.00. Your script should stop here.
# 5056 days have passed! Your final score is €0.00. Your script should stop here.
# 5057 days have passed! Your final score is €0.00. Your script should stop here.
# 5058 days have passed! Your final score is €0.00. Your script should stop here.
# 5059 days have passed! Your final score is €0.00. Your script should stop here.
# 5060 days have passed! Your final score is €0.00. Your script should stop here.
# 5061 days have passed! Your final score is €0.00. Your script should stop here.
# 5062 days have passed! Your final score is €0.00. Your script should stop here.
# 5063 days have passed! Your final score is €0.00. Your script should stop here.
# 5064 days have passed! Your final score is €0.00. Your script should stop here.
# 5065 days have passed! Your final score is €0.00. Your script should stop here.
# 5066 days have passed! Your final score is €0.00. Your script should stop here.
# 5067 days have passed! Your final score is €0.00. Your script should stop here.
# 5068 days have passed! Your final score is €0.00. Your script should stop here.
# 5069 days have passed! Your final score is €0.00. Your script should stop here.
# 5070 days have passed! Your final score is €0.00. Your script should stop here.
# 5071 days have passed! Your final score is €0.00. Your script should stop here.
# 5072 days have passed! Your final score is €0.00. Your script should stop here.
# 5073 days have passed! Your final score is €0.00. Your script should stop here.
# 5074 days have passed! Your final score is €0.00. Your script should stop here.
# 5075 days have passed! Your final score is €0.00. Your script should stop here.
# 5076 days have passed! Your final score is €0.00. Your script should stop here.
# 5077 days have passed! Your final score is €0.00. Your script should stop here.
# 5078 days have passed! Your final score is €0.00. Your script should stop here.
# 5079 days have passed! Your final score is €0.00. Your script should stop here.
# 5080 days have passed! Your final score is €0.00. Your script should stop here.
# 5081 days have passed! Your final score is €0.00. Your script should stop here.
# 5082 days have passed! Your final score is €0.00. Your script should stop here.
# 5083 days have passed! Your final score is €0.00. Your script should stop here.
# 5084 days have passed! Your final score is €0.00. Your script should stop here.
# 5085 days have passed! Your final score is €0.00. Your script should stop here.
# 5086 days have passed! Your final score is €0.00. Your script should stop here.
# 5087 days have passed! Your final score is €0.00. Your script should stop here.
# 5088 days have passed! Your final score is €0.00. Your script should stop here.
# 5089 days have passed! Your final score is €0.00. Your script should stop here.
# 5090 days have passed! Your final score is €0.00. Your script should stop here.
# 5091 days have passed! Your final score is €0.00. Your script should stop here.
# 5092 days have passed! Your final score is €0.00. Your script should stop here.
# 5093 days have passed! Your final score is €0.00. Your script should stop here.
# 5094 days have passed! Your final score is €0.00. Your script should stop here.
# 5095 days have passed! Your final score is €0.00. Your script should stop here.
# 5096 days have passed! Your final score is €0.00. Your script should stop here.
# 5097 days have passed! Your final score is €0.00. Your script should stop here.
# 5098 days have passed! Your final score is €0.00. Your script should stop here.
# 5099 days have passed! Your final score is €0.00. Your script should stop here.
# 5100 days have passed! Your final score is €0.00. Your script should stop here.
# 5101 days have passed! Your final score is €0.00. Your script should stop here.
# 5102 days have passed! Your final score is €0.00. Your script should stop here.
# 5103 days have passed! Your final score is €0.00. Your script should stop here.
# 5104 days have passed! Your final score is €0.00. Your script should stop here.
# 5105 days have passed! Your final score is €0.00. Your script should stop here.
# 5106 days have passed! Your final score is €0.00. Your script should stop here.
# 5107 days have passed! Your final score is €0.00. Your script should stop here.
# 5108 days have passed! Your final score is €0.00. Your script should stop here.
# 5109 days have passed! Your final score is €0.00. Your script should stop here.
# 5110 days have passed! Your final score is €0.00. Your script should stop here.
# 5111 days have passed! Your final score is €0.00. Your script should stop here.
# 5112 days have passed! Your final score is €0.00. Your script should stop here.
# 5113 days have passed! Your final score is €0.00. Your script should stop here.
# 5114 days have passed! Your final score is €0.00. Your script should stop here.
# 5115 days have passed! Your final score is €0.00. Your script should stop here.
# 5116 days have passed! Your final score is €0.00. Your script should stop here.
# 5117 days have passed! Your final score is €0.00. Your script should stop here.
# 5118 days have passed! Your final score is €0.00. Your script should stop here.
# 5119 days have passed! Your final score is €0.00. Your script should stop here.
# 5120 days have passed! Your final score is €0.00. Your script should stop here.
# 5121 days have passed! Your final score is €0.00. Your script should stop here.
# 5122 days have passed! Your final score is €0.00. Your script should stop here.
# 5123 days have passed! Your final score is €0.00. Your script should stop here.
# 5124 days have passed! Your final score is €0.00. Your script should stop here.
# 5125 days have passed! Your final score is €0.00. Your script should stop here.
# 5126 days have passed! Your final score is €0.00. Your script should stop here.
# 5127 days have passed! Your final score is €0.00. Your script should stop here.
# 5128 days have passed! Your final score is €0.00. Your script should stop here.
# 5129 days have passed! Your final score is €0.00. Your script should stop here.
# 5130 days have passed! Your final score is €0.00. Your script should stop here.
# 5131 days have passed! Your final score is €0.00. Your script should stop here.
# 5132 days have passed! Your final score is €0.00. Your script should stop here.
# 5133 days have passed! Your final score is €0.00. Your script should stop here.
# 5134 days have passed! Your final score is €0.00. Your script should stop here.
# 5135 days have passed! Your final score is €0.00. Your script should stop here.
# 5136 days have passed! Your final score is €0.00. Your script should stop here.
# 5137 days have passed! Your final score is €0.00. Your script should stop here.
# 5138 days have passed! Your final score is €0.00. Your script should stop here.
# 5139 days have passed! Your final score is €0.00. Your script should stop here.
# 5140 days have passed! Your final score is €0.00. Your script should stop here.
# 5141 days have passed! Your final score is €0.00. Your script should stop here.
# 5142 days have passed! Your final score is €0.00. Your script should stop here.
# 5143 days have passed! Your final score is €0.00. Your script should stop here.
# 5144 days have passed! Your final score is €0.00. Your script should stop here.
# 5145 days have passed! Your final score is €0.00. Your script should stop here.
# 5146 days have passed! Your final score is €0.00. Your script should stop here.
# 5147 days have passed! Your final score is €0.00. Your script should stop here.
# 5148 days have passed! Your final score is €0.00. Your script should stop here.
# 5149 days have passed! Your final score is €0.00. Your script should stop here.
# 5150 days have passed! Your final score is €0.00. Your script should stop here.
# 5151 days have passed! Your final score is €0.00. Your script should stop here.
# 5152 days have passed! Your final score is €0.00. Your script should stop here.
# 5153 days have passed! Your final score is €0.00. Your script should stop here.
# 5154 days have passed! Your final score is €0.00. Your script should stop here.
# 5155 days have passed! Your final score is €0.00. Your script should stop here.
# 5156 days have passed! Your final score is €0.00. Your script should stop here.
# 5157 days have passed! Your final score is €0.00. Your script should stop here.
# 5158 days have passed! Your final score is €0.00. Your script should stop here.
# 5159 days have passed! Your final score is €0.00. Your script should stop here.
# 5160 days have passed! Your final score is €0.00. Your script should stop here.
# 5161 days have passed! Your final score is €0.00. Your script should stop here.
# 5162 days have passed! Your final score is €0.00. Your script should stop here.
# 5163 days have passed! Your final score is €0.00. Your script should stop here.
# 5164 days have passed! Your final score is €0.00. Your script should stop here.
# 5165 days have passed! Your final score is €0.00. Your script should stop here.
# 5166 days have passed! Your final score is €0.00. Your script should stop here.
# 5167 days have passed! Your final score is €0.00. Your script should stop here.
# 5168 days have passed! Your final score is €0.00. Your script should stop here.
# 5169 days have passed! Your final score is €0.00. Your script should stop here.
# 5170 days have passed! Your final score is €0.00. Your script should stop here.
# 5171 days have passed! Your final score is €0.00. Your script should stop here.
# 5172 days have passed! Your final score is €0.00. Your script should stop here.
# 5173 days have passed! Your final score is €0.00. Your script should stop here.
# 5174 days have passed! Your final score is €0.00. Your script should stop here.
# 5175 days have passed! Your final score is €0.00. Your script should stop here.
# 5176 days have passed! Your final score is €0.00. Your script should stop here.
# 5177 days have passed! Your final score is €0.00. Your script should stop here.
# 5178 days have passed! Your final score is €0.00. Your script should stop here.
# 5179 days have passed! Your final score is €0.00. Your script should stop here.
# 5180 days have passed! Your final score is €0.00. Your script should stop here.
# 5181 days have passed! Your final score is €0.00. Your script should stop here.
# 5182 days have passed! Your final score is €0.00. Your script should stop here.
# 5183 days have passed! Your final score is €0.00. Your script should stop here.
# 5184 days have passed! Your final score is €0.00. Your script should stop here.
# 5185 days have passed! Your final score is €0.00. Your script should stop here.
# 5186 days have passed! Your final score is €0.00. Your script should stop here.
# 5187 days have passed! Your final score is €0.00. Your script should stop here.
# 5188 days have passed! Your final score is €0.00. Your script should stop here.
# 5189 days have passed! Your final score is €0.00. Your script should stop here.
# 5190 days have passed! Your final score is €0.00. Your script should stop here.
# 5191 days have passed! Your final score is €0.00. Your script should stop here.
# 5192 days have passed! Your final score is €0.00. Your script should stop here.
# 5193 days have passed! Your final score is €0.00. Your script should stop here.
# 5194 days have passed! Your final score is €0.00. Your script should stop here.
# 5195 days have passed! Your final score is €0.00. Your script should stop here.
# 5196 days have passed! Your final score is €0.00. Your script should stop here.
# 5197 days have passed! Your final score is €0.00. Your script should stop here.
# 5198 days have passed! Your final score is €0.00. Your script should stop here.
# 5199 days have passed! Your final score is €0.00. Your script should stop here.
# 5200 days have passed! Your final score is €0.00. Your script should stop here.
# 5201 days have passed! Your final score is €0.00. Your script should stop here.
# 5202 days have passed! Your final score is €0.00. Your script should stop here.
# 5203 days have passed! Your final score is €0.00. Your script should stop here.
# 5204 days have passed! Your final score is €0.00. Your script should stop here.
# 5205 days have passed! Your final score is €0.00. Your script should stop here.
# 5206 days have passed! Your final score is €0.00. Your script should stop here.
# 5207 days have passed! Your final score is €0.00. Your script should stop here.
# 5208 days have passed! Your final score is €0.00. Your script should stop here.
# 5209 days have passed! Your final score is €0.00. Your script should stop here.
# 5210 days have passed! Your final score is €0.00. Your script should stop here.
# 5211 days have passed! Your final score is €0.00. Your script should stop here.
# 5212 days have passed! Your final score is €0.00. Your script should stop here.
# 5213 days have passed! Your final score is €0.00. Your script should stop here.
# 5214 days have passed! Your final score is €0.00. Your script should stop here.
# 5215 days have passed! Your final score is €0.00. Your script should stop here.
# 5216 days have passed! Your final score is €0.00. Your script should stop here.
# 5217 days have passed! Your final score is €0.00. Your script should stop here.
# 5218 days have passed! Your final score is €0.00. Your script should stop here.
# 5219 days have passed! Your final score is €0.00. Your script should stop here.
# 5220 days have passed! Your final score is €0.00. Your script should stop here.
# 5221 days have passed! Your final score is €0.00. Your script should stop here.
# 5222 days have passed! Your final score is €0.00. Your script should stop here.
# 5223 days have passed! Your final score is €0.00. Your script should stop here.
# 5224 days have passed! Your final score is €0.00. Your script should stop here.
# 5225 days have passed! Your final score is €0.00. Your script should stop here.
# 5226 days have passed! Your final score is €0.00. Your script should stop here.
# 5227 days have passed! Your final score is €0.00. Your script should stop here.
# 5228 days have passed! Your final score is €0.00. Your script should stop here.
# 5229 days have passed! Your final score is €0.00. Your script should stop here.
# 5230 days have passed! Your final score is €0.00. Your script should stop here.
# 5231 days have passed! Your final score is €0.00. Your script should stop here.
# 5232 days have passed! Your final score is €0.00. Your script should stop here.
# 5233 days have passed! Your final score is €0.00. Your script should stop here.
# 5234 days have passed! Your final score is €0.00. Your script should stop here.
# 5235 days have passed! Your final score is €0.00. Your script should stop here.
# 5236 days have passed! Your final score is €0.00. Your script should stop here.
# 5237 days have passed! Your final score is €0.00. Your script should stop here.
# 5238 days have passed! Your final score is €0.00. Your script should stop here.
# 5239 days have passed! Your final score is €0.00. Your script should stop here.
# 5240 days have passed! Your final score is €0.00. Your script should stop here.
# 5241 days have passed! Your final score is €0.00. Your script should stop here.
# 5242 days have passed! Your final score is €0.00. Your script should stop here.
# 5243 days have passed! Your final score is €0.00. Your script should stop here.
# 5244 days have passed! Your final score is €0.00. Your script should stop here.
# 5245 days have passed! Your final score is €0.00. Your script should stop here.
# 5246 days have passed! Your final score is €0.00. Your script should stop here.
# 5247 days have passed! Your final score is €0.00. Your script should stop here.
# 5248 days have passed! Your final score is €0.00. Your script should stop here.
# 5249 days have passed! Your final score is €0.00. Your script should stop here.
# 5250 days have passed! Your final score is €0.00. Your script should stop here.
# 5251 days have passed! Your final score is €0.00. Your script should stop here.
# 5252 days have passed! Your final score is €0.00. Your script should stop here.
# 5253 days have passed! Your final score is €0.00. Your script should stop here.
# 5254 days have passed! Your final score is €0.00. Your script should stop here.
# 5255 days have passed! Your final score is €0.00. Your script should stop here.
# 5256 days have passed! Your final score is €0.00. Your script should stop here.
# 5257 days have passed! Your final score is €0.00. Your script should stop here.
# 5258 days have passed! Your final score is €0.00. Your script should stop here.
# 5259 days have passed! Your final score is €0.00. Your script should stop here.
# 5260 days have passed! Your final score is €0.00. Your script should stop here.
# 5261 days have passed! Your final score is €0.00. Your script should stop here.
# 5262 days have passed! Your final score is €0.00. Your script should stop here.
# 5263 days have passed! Your final score is €0.00. Your script should stop here.
# 5264 days have passed! Your final score is €0.00. Your script should stop here.
# 5265 days have passed! Your final score is €0.00. Your script should stop here.
# 5266 days have passed! Your final score is €0.00. Your script should stop here.
# 5267 days have passed! Your final score is €0.00. Your script should stop here.
# 5268 days have passed! Your final score is €0.00. Your script should stop here.
# 5269 days have passed! Your final score is €0.00. Your script should stop here.
# 5270 days have passed! Your final score is €0.00. Your script should stop here.
# 5271 days have passed! Your final score is €0.00. Your script should stop here.
# 5272 days have passed! Your final score is €0.00. Your script should stop here.
# 5273 days have passed! Your final score is €0.00. Your script should stop here.
# 5274 days have passed! Your final score is €0.00. Your script should stop here.
# 5275 days have passed! Your final score is €0.00. Your script should stop here.
# 5276 days have passed! Your final score is €0.00. Your script should stop here.
# 5277 days have passed! Your final score is €0.00. Your script should stop here.
# 5278 days have passed! Your final score is €0.00. Your script should stop here.
# 5279 days have passed! Your final score is €0.00. Your script should stop here.
# 5280 days have passed! Your final score is €0.00. Your script should stop here.
# 5281 days have passed! Your final score is €0.00. Your script should stop here.
# 5282 days have passed! Your final score is €0.00. Your script should stop here.
# 5283 days have passed! Your final score is €0.00. Your script should stop here.
# 5284 days have passed! Your final score is €0.00. Your script should stop here.
# 5285 days have passed! Your final score is €0.00. Your script should stop here.
# 5286 days have passed! Your final score is €0.00. Your script should stop here.
# 5287 days have passed! Your final score is €0.00. Your script should stop here.
# 5288 days have passed! Your final score is €0.00. Your script should stop here.
# 5289 days have passed! Your final score is €0.00. Your script should stop here.
# 5290 days have passed! Your final score is €0.00. Your script should stop here.
# 5291 days have passed! Your final score is €0.00. Your script should stop here.
# 5292 days have passed! Your final score is €0.00. Your script should stop here.
# 5293 days have passed! Your final score is €0.00. Your script should stop here.
# 5294 days have passed! Your final score is €0.00. Your script should stop here.
# 5295 days have passed! Your final score is €0.00. Your script should stop here.
# 5296 days have passed! Your final score is €0.00. Your script should stop here.
# 5297 days have passed! Your final score is €0.00. Your script should stop here.
# 5298 days have passed! Your final score is €0.00. Your script should stop here.
# 5299 days have passed! Your final score is €0.00. Your script should stop here.
# 5300 days have passed! Your final score is €0.00. Your script should stop here.
# 5301 days have passed! Your final score is €0.00. Your script should stop here.
# 5302 days have passed! Your final score is €0.00. Your script should stop here.
# 5303 days have passed! Your final score is €0.00. Your script should stop here.
# 5304 days have passed! Your final score is €0.00. Your script should stop here.
# 5305 days have passed! Your final score is €0.00. Your script should stop here.
# 5306 days have passed! Your final score is €0.00. Your script should stop here.
# 5307 days have passed! Your final score is €0.00. Your script should stop here.
# 5308 days have passed! Your final score is €0.00. Your script should stop here.
# 5309 days have passed! Your final score is €0.00. Your script should stop here.
# 5310 days have passed! Your final score is €0.00. Your script should stop here.
# 5311 days have passed! Your final score is €0.00. Your script should stop here.
# 5312 days have passed! Your final score is €0.00. Your script should stop here.
# 5313 days have passed! Your final score is €0.00. Your script should stop here.
# 5314 days have passed! Your final score is €0.00. Your script should stop here.
# 5315 days have passed! Your final score is €0.00. Your script should stop here.
# 5316 days have passed! Your final score is €0.00. Your script should stop here.
# 5317 days have passed! Your final score is €0.00. Your script should stop here.
# 5318 days have passed! Your final score is €0.00. Your script should stop here.
# 5319 days have passed! Your final score is €0.00. Your script should stop here.
# 5320 days have passed! Your final score is €0.00. Your script should stop here.
# 5321 days have passed! Your final score is €0.00. Your script should stop here.
# 5322 days have passed! Your final score is €0.00. Your script should stop here.
# 5323 days have passed! Your final score is €0.00. Your script should stop here.
# 5324 days have passed! Your final score is €0.00. Your script should stop here.
# 5325 days have passed! Your final score is €0.00. Your script should stop here.
# 5326 days have passed! Your final score is €0.00. Your script should stop here.
# 5327 days have passed! Your final score is €0.00. Your script should stop here.
# 5328 days have passed! Your final score is €0.00. Your script should stop here.
# 5329 days have passed! Your final score is €0.00. Your script should stop here.
# 5330 days have passed! Your final score is €0.00. Your script should stop here.
# 5331 days have passed! Your final score is €0.00. Your script should stop here.
# 5332 days have passed! Your final score is €0.00. Your script should stop here.
# 5333 days have passed! Your final score is €0.00. Your script should stop here.
# 5334 days have passed! Your final score is €0.00. Your script should stop here.
# 5335 days have passed! Your final score is €0.00. Your script should stop here.
# 5336 days have passed! Your final score is €0.00. Your script should stop here.
# 5337 days have passed! Your final score is €0.00. Your script should stop here.
# 5338 days have passed! Your final score is €0.00. Your script should stop here.
# 5339 days have passed! Your final score is €0.00. Your script should stop here.
# 5340 days have passed! Your final score is €0.00. Your script should stop here.
# 5341 days have passed! Your final score is €0.00. Your script should stop here.
# 5342 days have passed! Your final score is €0.00. Your script should stop here.
# 5343 days have passed! Your final score is €0.00. Your script should stop here.
# 5344 days have passed! Your final score is €0.00. Your script should stop here.
# 5345 days have passed! Your final score is €0.00. Your script should stop here.
# 5346 days have passed! Your final score is €0.00. Your script should stop here.
# 5347 days have passed! Your final score is €0.00. Your script should stop here.
# 5348 days have passed! Your final score is €0.00. Your script should stop here.
# 5349 days have passed! Your final score is €0.00. Your script should stop here.
# 5350 days have passed! Your final score is €0.00. Your script should stop here.
# 5351 days have passed! Your final score is €0.00. Your script should stop here.
# 5352 days have passed! Your final score is €0.00. Your script should stop here.
# 5353 days have passed! Your final score is €0.00. Your script should stop here.
# 5354 days have passed! Your final score is €0.00. Your script should stop here.
# 5355 days have passed! Your final score is €0.00. Your script should stop here.
# 5356 days have passed! Your final score is €0.00. Your script should stop here.
# 5357 days have passed! Your final score is €0.00. Your script should stop here.
# 5358 days have passed! Your final score is €0.00. Your script should stop here.
# 5359 days have passed! Your final score is €0.00. Your script should stop here.
# 5360 days have passed! Your final score is €0.00. Your script should stop here.
# 5361 days have passed! Your final score is €0.00. Your script should stop here.
# 5362 days have passed! Your final score is €0.00. Your script should stop here.
# 5363 days have passed! Your final score is €0.00. Your script should stop here.
# 5364 days have passed! Your final score is €0.00. Your script should stop here.
# 5365 days have passed! Your final score is €0.00. Your script should stop here.
# 5366 days have passed! Your final score is €0.00. Your script should stop here.
# 5367 days have passed! Your final score is €0.00. Your script should stop here.
# 5368 days have passed! Your final score is €0.00. Your script should stop here.
# 5369 days have passed! Your final score is €0.00. Your script should stop here.
# 5370 days have passed! Your final score is €0.00. Your script should stop here.
# 5371 days have passed! Your final score is €0.00. Your script should stop here.
# 5372 days have passed! Your final score is €0.00. Your script should stop here.
# 5373 days have passed! Your final score is €0.00. Your script should stop here.
# 5374 days have passed! Your final score is €0.00. Your script should stop here.
# 5375 days have passed! Your final score is €0.00. Your script should stop here.
# 5376 days have passed! Your final score is €0.00. Your script should stop here.
# 5377 days have passed! Your final score is €0.00. Your script should stop here.
# 5378 days have passed! Your final score is €0.00. Your script should stop here.
# 5379 days have passed! Your final score is €0.00. Your script should stop here.
# 5380 days have passed! Your final score is €0.00. Your script should stop here.
# 5381 days have passed! Your final score is €0.00. Your script should stop here.
# 5382 days have passed! Your final score is €0.00. Your script should stop here.
# 5383 days have passed! Your final score is €0.00. Your script should stop here.
# 5384 days have passed! Your final score is €0.00. Your script should stop here.
# 5385 days have passed! Your final score is €0.00. Your script should stop here.
# 5386 days have passed! Your final score is €0.00. Your script should stop here.
# 5387 days have passed! Your final score is €0.00. Your script should stop here.
# 5388 days have passed! Your final score is €0.00. Your script should stop here.
# 5389 days have passed! Your final score is €0.00. Your script should stop here.
# 5390 days have passed! Your final score is €0.00. Your script should stop here.
# 5391 days have passed! Your final score is €0.00. Your script should stop here.
# 5392 days have passed! Your final score is €0.00. Your script should stop here.
# 5393 days have passed! Your final score is €0.00. Your script should stop here.
# 5394 days have passed! Your final score is €0.00. Your script should stop here.
# 5395 days have passed! Your final score is €0.00. Your script should stop here.
# 5396 days have passed! Your final score is €0.00. Your script should stop here.
# 5397 days have passed! Your final score is €0.00. Your script should stop here.
# 5398 days have passed! Your final score is €0.00. Your script should stop here.
# 5399 days have passed! Your final score is €0.00. Your script should stop here.
# 5400 days have passed! Your final score is €0.00. Your script should stop here.
# 5401 days have passed! Your final score is €0.00. Your script should stop here.
# 5402 days have passed! Your final score is €0.00. Your script should stop here.
# 5403 days have passed! Your final score is €0.00. Your script should stop here.
# 5404 days have passed! Your final score is €0.00. Your script should stop here.
# 5405 days have passed! Your final score is €0.00. Your script should stop here.
# 5406 days have passed! Your final score is €0.00. Your script should stop here.
# 5407 days have passed! Your final score is €0.00. Your script should stop here.
# 5408 days have passed! Your final score is €0.00. Your script should stop here.
# 5409 days have passed! Your final score is €0.00. Your script should stop here.
# 5410 days have passed! Your final score is €0.00. Your script should stop here.
# 5411 days have passed! Your final score is €0.00. Your script should stop here.
# 5412 days have passed! Your final score is €0.00. Your script should stop here.
# 5413 days have passed! Your final score is €0.00. Your script should stop here.
# 5414 days have passed! Your final score is €0.00. Your script should stop here.
# 5415 days have passed! Your final score is €0.00. Your script should stop here.
# 5416 days have passed! Your final score is €0.00. Your script should stop here.
# 5417 days have passed! Your final score is €0.00. Your script should stop here.
# 5418 days have passed! Your final score is €0.00. Your script should stop here.
# 5419 days have passed! Your final score is €0.00. Your script should stop here.
# 5420 days have passed! Your final score is €0.00. Your script should stop here.
# 5421 days have passed! Your final score is €0.00. Your script should stop here.
# 5422 days have passed! Your final score is €0.00. Your script should stop here.
# 5423 days have passed! Your final score is €0.00. Your script should stop here.
# 5424 days have passed! Your final score is €0.00. Your script should stop here.
# 5425 days have passed! Your final score is €0.00. Your script should stop here.
# 5426 days have passed! Your final score is €0.00. Your script should stop here.
# 5427 days have passed! Your final score is €0.00. Your script should stop here.
# 5428 days have passed! Your final score is €0.00. Your script should stop here.
# 5429 days have passed! Your final score is €0.00. Your script should stop here.
# 5430 days have passed! Your final score is €0.00. Your script should stop here.
# 5431 days have passed! Your final score is €0.00. Your script should stop here.
# 5432 days have passed! Your final score is €0.00. Your script should stop here.
# 5433 days have passed! Your final score is €0.00. Your script should stop here.
# 5434 days have passed! Your final score is €0.00. Your script should stop here.
# 5435 days have passed! Your final score is €0.00. Your script should stop here.
# 5436 days have passed! Your final score is €0.00. Your script should stop here.
# 5437 days have passed! Your final score is €0.00. Your script should stop here.
# 5438 days have passed! Your final score is €0.00. Your script should stop here.
# 5439 days have passed! Your final score is €0.00. Your script should stop here.
# 5440 days have passed! Your final score is €0.00. Your script should stop here.
# 5441 days have passed! Your final score is €0.00. Your script should stop here.
# 5442 days have passed! Your final score is €0.00. Your script should stop here.
# 5443 days have passed! Your final score is €0.00. Your script should stop here.
# 5444 days have passed! Your final score is €0.00. Your script should stop here.
# 5445 days have passed! Your final score is €0.00. Your script should stop here.
# 5446 days have passed! Your final score is €0.00. Your script should stop here.
# 5447 days have passed! Your final score is €0.00. Your script should stop here.
# 5448 days have passed! Your final score is €0.00. Your script should stop here.
# 5449 days have passed! Your final score is €0.00. Your script should stop here.
# 5450 days have passed! Your final score is €0.00. Your script should stop here.
# 5451 days have passed! Your final score is €0.00. Your script should stop here.
# 5452 days have passed! Your final score is €0.00. Your script should stop here.
# 5453 days have passed! Your final score is €0.00. Your script should stop here.
# 5454 days have passed! Your final score is €0.00. Your script should stop here.
# 5455 days have passed! Your final score is €0.00. Your script should stop here.
# 5456 days have passed! Your final score is €0.00. Your script should stop here.
# 5457 days have passed! Your final score is €0.00. Your script should stop here.
# 5458 days have passed! Your final score is €0.00. Your script should stop here.
# 5459 days have passed! Your final score is €0.00. Your script should stop here.
# 5460 days have passed! Your final score is €0.00. Your script should stop here.
# 5461 days have passed! Your final score is €0.00. Your script should stop here.
# 5462 days have passed! Your final score is €0.00. Your script should stop here.
# 5463 days have passed! Your final score is €0.00. Your script should stop here.
# 5464 days have passed! Your final score is €0.00. Your script should stop here.
# 5465 days have passed! Your final score is €0.00. Your script should stop here.
# 5466 days have passed! Your final score is €0.00. Your script should stop here.
# 5467 days have passed! Your final score is €0.00. Your script should stop here.
# 5468 days have passed! Your final score is €0.00. Your script should stop here.
# 5469 days have passed! Your final score is €0.00. Your script should stop here.
# 5470 days have passed! Your final score is €0.00. Your script should stop here.
# 5471 days have passed! Your final score is €0.00. Your script should stop here.
# 5472 days have passed! Your final score is €0.00. Your script should stop here.
# 5473 days have passed! Your final score is €0.00. Your script should stop here.
# 5474 days have passed! Your final score is €0.00. Your script should stop here.
# 5475 days have passed! Your final score is €0.00. Your script should stop here.
# 5476 days have passed! Your final score is €0.00. Your script should stop here.
# 5477 days have passed! Your final score is €0.00. Your script should stop here.
# 5478 days have passed! Your final score is €0.00. Your script should stop here.
# 5479 days have passed! Your final score is €0.00. Your script should stop here.
# 5480 days have passed! Your final score is €0.00. Your script should stop here.
# 5481 days have passed! Your final score is €0.00. Your script should stop here.
# 5482 days have passed! Your final score is €0.00. Your script should stop here.
# 5483 days have passed! Your final score is €0.00. Your script should stop here.
# 5484 days have passed! Your final score is €0.00. Your script should stop here.
# 5485 days have passed! Your final score is €0.00. Your script should stop here.
# 5486 days have passed! Your final score is €0.00. Your script should stop here.
# 5487 days have passed! Your final score is €0.00. Your script should stop here.
# 5488 days have passed! Your final score is €0.00. Your script should stop here.
# 5489 days have passed! Your final score is €0.00. Your script should stop here.
# 5490 days have passed! Your final score is €0.00. Your script should stop here.
# 5491 days have passed! Your final score is €0.00. Your script should stop here.
# 5492 days have passed! Your final score is €0.00. Your script should stop here.
# 5493 days have passed! Your final score is €0.00. Your script should stop here.
# 5494 days have passed! Your final score is €0.00. Your script should stop here.
# 5495 days have passed! Your final score is €0.00. Your script should stop here.
# 5496 days have passed! Your final score is €0.00. Your script should stop here.
# 5497 days have passed! Your final score is €0.00. Your script should stop here.
# 5498 days have passed! Your final score is €0.00. Your script should stop here.
# 5499 days have passed! Your final score is €0.00. Your script should stop here.
# 5500 days have passed! Your final score is €0.00. Your script should stop here.
# 5501 days have passed! Your final score is €0.00. Your script should stop here.
# 5502 days have passed! Your final score is €0.00. Your script should stop here.
# 5503 days have passed! Your final score is €0.00. Your script should stop here.
# 5504 days have passed! Your final score is €0.00. Your script should stop here.
# 5505 days have passed! Your final score is €0.00. Your script should stop here.
# 5506 days have passed! Your final score is €0.00. Your script should stop here.
# 5507 days have passed! Your final score is €0.00. Your script should stop here.
# 5508 days have passed! Your final score is €0.00. Your script should stop here.
# 5509 days have passed! Your final score is €0.00. Your script should stop here.
# 5510 days have passed! Your final score is €0.00. Your script should stop here.
# 5511 days have passed! Your final score is €0.00. Your script should stop here.
# 5512 days have passed! Your final score is €0.00. Your script should stop here.
# 5513 days have passed! Your final score is €0.00. Your script should stop here.
# 5514 days have passed! Your final score is €0.00. Your script should stop here.
# 5515 days have passed! Your final score is €0.00. Your script should stop here.
# 5516 days have passed! Your final score is €0.00. Your script should stop here.
# 5517 days have passed! Your final score is €0.00. Your script should stop here.
# 5518 days have passed! Your final score is €0.00. Your script should stop here.
# 5519 days have passed! Your final score is €0.00. Your script should stop here.
# 5520 days have passed! Your final score is €0.00. Your script should stop here.
# 5521 days have passed! Your final score is €0.00. Your script should stop here.
# 5522 days have passed! Your final score is €0.00. Your script should stop here.
# 5523 days have passed! Your final score is €0.00. Your script should stop here.
# 5524 days have passed! Your final score is €0.00. Your script should stop here.
# 5525 days have passed! Your final score is €0.00. Your script should stop here.
# 5526 days have passed! Your final score is €0.00. Your script should stop here.
# 5527 days have passed! Your final score is €0.00. Your script should stop here.
# 5528 days have passed! Your final score is €0.00. Your script should stop here.
# 5529 days have passed! Your final score is €0.00. Your script should stop here.
# 5530 days have passed! Your final score is €0.00. Your script should stop here.
# 5531 days have passed! Your final score is €0.00. Your script should stop here.
# 5532 days have passed! Your final score is €0.00. Your script should stop here.
# 5533 days have passed! Your final score is €0.00. Your script should stop here.
# 5534 days have passed! Your final score is €0.00. Your script should stop here.
# 5535 days have passed! Your final score is €0.00. Your script should stop here.
# 5536 days have passed! Your final score is €0.00. Your script should stop here.
# 5537 days have passed! Your final score is €0.00. Your script should stop here.
# 5538 days have passed! Your final score is €0.00. Your script should stop here.
# 5539 days have passed! Your final score is €0.00. Your script should stop here.
# 5540 days have passed! Your final score is €0.00. Your script should stop here.
# 5541 days have passed! Your final score is €0.00. Your script should stop here.
# 5542 days have passed! Your final score is €0.00. Your script should stop here.
# 5543 days have passed! Your final score is €0.00. Your script should stop here.
# 5544 days have passed! Your final score is €0.00. Your script should stop here.
# 5545 days have passed! Your final score is €0.00. Your script should stop here.
# 5546 days have passed! Your final score is €0.00. Your script should stop here.
# 5547 days have passed! Your final score is €0.00. Your script should stop here.
# 5548 days have passed! Your final score is €0.00. Your script should stop here.
# 5549 days have passed! Your final score is €0.00. Your script should stop here.
# 5550 days have passed! Your final score is €0.00. Your script should stop here.
# 5551 days have passed! Your final score is €0.00. Your script should stop here.
# 5552 days have passed! Your final score is €0.00. Your script should stop here.
# 5553 days have passed! Your final score is €0.00. Your script should stop here.
# 5554 days have passed! Your final score is €0.00. Your script should stop here.
# 5555 days have passed! Your final score is €0.00. Your script should stop here.
# 5556 days have passed! Your final score is €0.00. Your script should stop here.
# 5557 days have passed! Your final score is €0.00. Your script should stop here.
# 5558 days have passed! Your final score is €0.00. Your script should stop here.
# 5559 days have passed! Your final score is €0.00. Your script should stop here.
# 5560 days have passed! Your final score is €0.00. Your script should stop here.
# 5561 days have passed! Your final score is €0.00. Your script should stop here.
# 5562 days have passed! Your final score is €0.00. Your script should stop here.
# 5563 days have passed! Your final score is €0.00. Your script should stop here.
# 5564 days have passed! Your final score is €0.00. Your script should stop here.
# 5565 days have passed! Your final score is €0.00. Your script should stop here.
# 5566 days have passed! Your final score is €0.00. Your script should stop here.
# 5567 days have passed! Your final score is €0.00. Your script should stop here.
# 5568 days have passed! Your final score is €0.00. Your script should stop here.
# 5569 days have passed! Your final score is €0.00. Your script should stop here.
# 5570 days have passed! Your final score is €0.00. Your script should stop here.
# 5571 days have passed! Your final score is €0.00. Your script should stop here.
# 5572 days have passed! Your final score is €0.00. Your script should stop here.
# 5573 days have passed! Your final score is €0.00. Your script should stop here.
# 5574 days have passed! Your final score is €0.00. Your script should stop here.
# 5575 days have passed! Your final score is €0.00. Your script should stop here.
# 5576 days have passed! Your final score is €0.00. Your script should stop here.
# 5577 days have passed! Your final score is €0.00. Your script should stop here.
# 5578 days have passed! Your final score is €0.00. Your script should stop here.
# 5579 days have passed! Your final score is €0.00. Your script should stop here.
# 5580 days have passed! Your final score is €0.00. Your script should stop here.
# 5581 days have passed! Your final score is €0.00. Your script should stop here.
# 5582 days have passed! Your final score is €0.00. Your script should stop here.
# 5583 days have passed! Your final score is €0.00. Your script should stop here.
# 5584 days have passed! Your final score is €0.00. Your script should stop here.
# 5585 days have passed! Your final score is €0.00. Your script should stop here.
# 5586 days have passed! Your final score is €0.00. Your script should stop here.
# 5587 days have passed! Your final score is €0.00. Your script should stop here.
# 5588 days have passed! Your final score is €0.00. Your script should stop here.
# 5589 days have passed! Your final score is €0.00. Your script should stop here.
# 5590 days have passed! Your final score is €0.00. Your script should stop here.
# 5591 days have passed! Your final score is €0.00. Your script should stop here.
# 5592 days have passed! Your final score is €0.00. Your script should stop here.
# 5593 days have passed! Your final score is €0.00. Your script should stop here.
# 5594 days have passed! Your final score is €0.00. Your script should stop here.
# 5595 days have passed! Your final score is €0.00. Your script should stop here.
# 5596 days have passed! Your final score is €0.00. Your script should stop here.
# 5597 days have passed! Your final score is €0.00. Your script should stop here.
# 5598 days have passed! Your final score is €0.00. Your script should stop here.
# 5599 days have passed! Your final score is €0.00. Your script should stop here.
# ...
# 9799 days have passed! Your final score is €0.00. Your script should stop here.
# 9800 days have passed! Your final score is €0.00. Your script should stop here.
# 9801 days have passed! Your final score is €0.00. Your script should stop here.
# 9802 days have passed! Your final score is €0.00. Your script should stop here.
# 9803 days have passed! Your final score is €0.00. Your script should stop here.
# 9804 days have passed! Your final score is €0.00. Your script should stop here.
# 9805 days have passed! Your final score is €0.00. Your script should stop here.
# 9806 days have passed! Your final score is €0.00. Your script should stop here.
# 9807 days have passed! Your final score is €0.00. Your script should stop here.
# 9808 days have passed! Your final score is €0.00. Your script should stop here.
# 9809 days have passed! Your final score is €0.00. Your script should stop here.
# 9810 days have passed! Your final score is €0.00. Your script should stop here.
# 9811 days have passed! Your final score is €0.00. Your script should stop here.
# 9812 days have passed! Your final score is €0.00. Your script should stop here.
# 9813 days have passed! Your final score is €0.00. Your script should stop here.
# 9814 days have passed! Your final score is €0.00. Your script should stop here.
# 9815 days have passed! Your final score is €0.00. Your script should stop here.
# 9816 days have passed! Your final score is €0.00. Your script should stop here.
# 9817 days have passed! Your final score is €0.00. Your script should stop here.
# 9818 days have passed! Your final score is €0.00. Your script should stop here.
# 9819 days have passed! Your final score is €0.00. Your script should stop here.
# 9820 days have passed! Your final score is €0.00. Your script should stop here.
# 9821 days have passed! Your final score is €0.00. Your script should stop here.
# 9822 days have passed! Your final score is €0.00. Your script should stop here.
# 9823 days have passed! Your final score is €0.00. Your script should stop here.
# 9824 days have passed! Your final score is €0.00. Your script should stop here.
# 9825 days have passed! Your final score is €0.00. Your script should stop here.
# 9826 days have passed! Your final score is €0.00. Your script should stop here.
# 9827 days have passed! Your final score is €0.00. Your script should stop here.
# 9828 days have passed! Your final score is €0.00. Your script should stop here.
# 9829 days have passed! Your final score is €0.00. Your script should stop here.
# 9830 days have passed! Your final score is €0.00. Your script should stop here.
# 9831 days have passed! Your final score is €0.00. Your script should stop here.
# 9832 days have passed! Your final score is €0.00. Your script should stop here.
# 9833 days have passed! Your final score is €0.00. Your script should stop here.
# 9834 days have passed! Your final score is €0.00. Your script should stop here.
# 9835 days have passed! Your final score is €0.00. Your script should stop here.
# 9836 days have passed! Your final score is €0.00. Your script should stop here.
# 9837 days have passed! Your final score is €0.00. Your script should stop here.
# 9838 days have passed! Your final score is €0.00. Your script should stop here.
# 9839 days have passed! Your final score is €0.00. Your script should stop here.
# 9840 days have passed! Your final score is €0.00. Your script should stop here.
# 9841 days have passed! Your final score is €0.00. Your script should stop here.
# 9842 days have passed! Your final score is €0.00. Your script should stop here.
# 9843 days have passed! Your final score is €0.00. Your script should stop here.
# 9844 days have passed! Your final score is €0.00. Your script should stop here.
# 9845 days have passed! Your final score is €0.00. Your script should stop here.
# 9846 days have passed! Your final score is €0.00. Your script should stop here.
# 9847 days have passed! Your final score is €0.00. Your script should stop here.
# 9848 days have passed! Your final score is €0.00. Your script should stop here.
# 9849 days have passed! Your final score is €0.00. Your script should stop here.
# 9850 days have passed! Your final score is €0.00. Your script should stop here.
# 9851 days have passed! Your final score is €0.00. Your script should stop here.
# 9852 days have passed! Your final score is €0.00. Your script should stop here.
# 9853 days have passed! Your final score is €0.00. Your script should stop here.
# 9854 days have passed! Your final score is €0.00. Your script should stop here.
# 9855 days have passed! Your final score is €0.00. Your script should stop here.
# 9856 days have passed! Your final score is €0.00. Your script should stop here.
# 9857 days have passed! Your final score is €0.00. Your script should stop here.
# 9858 days have passed! Your final score is €0.00. Your script should stop here.
# 9859 days have passed! Your final score is €0.00. Your script should stop here.
# 9860 days have passed! Your final score is €0.00. Your script should stop here.
# 9861 days have passed! Your final score is €0.00. Your script should stop here.
# 9862 days have passed! Your final score is €0.00. Your script should stop here.
# 9863 days have passed! Your final score is €0.00. Your script should stop here.
# 9864 days have passed! Your final score is €0.00. Your script should stop here.
# 9865 days have passed! Your final score is €0.00. Your script should stop here.
# 9866 days have passed! Your final score is €0.00. Your script should stop here.
# 9867 days have passed! Your final score is €0.00. Your script should stop here.
# 9868 days have passed! Your final score is €0.00. Your script should stop here.
# 9869 days have passed! Your final score is €0.00. Your script should stop here.
# 9870 days have passed! Your final score is €0.00. Your script should stop here.
# 9871 days have passed! Your final score is €0.00. Your script should stop here.
# 9872 days have passed! Your final score is €0.00. Your script should stop here.
# 9873 days have passed! Your final score is €0.00. Your script should stop here.
# 9874 days have passed! Your final score is €0.00. Your script should stop here.
# 9875 days have passed! Your final score is €0.00. Your script should stop here.
# 9876 days have passed! Your final score is €0.00. Your script should stop here.
# 9877 days have passed! Your final score is €0.00. Your script should stop here.
# 9878 days have passed! Your final score is €0.00. Your script should stop here.
# 9879 days have passed! Your final score is €0.00. Your script should stop here.
# 9880 days have passed! Your final score is €0.00. Your script should stop here.
# 9881 days have passed! Your final score is €0.00. Your script should stop here.
# 9882 days have passed! Your final score is €0.00. Your script should stop here.
# 9883 days have passed! Your final score is €0.00. Your script should stop here.
# 9884 days have passed! Your final score is €0.00. Your script should stop here.
# 9885 days have passed! Your final score is €0.00. Your script should stop here.
# 9886 days have passed! Your final score is €0.00. Your script should stop here.
# 9887 days have passed! Your final score is €0.00. Your script should stop here.
# 9888 days have passed! Your final score is €0.00. Your script should stop here.
# 9889 days have passed! Your final score is €0.00. Your script should stop here.
# 9890 days have passed! Your final score is €0.00. Your script should stop here.
# 9891 days have passed! Your final score is €0.00. Your script should stop here.
# 9892 days have passed! Your final score is €0.00. Your script should stop here.
# 9893 days have passed! Your final score is €0.00. Your script should stop here.
# 9894 days have passed! Your final score is €0.00. Your script should stop here.
# 9895 days have passed! Your final score is €0.00. Your script should stop here.
# 9896 days have passed! Your final score is €0.00. Your script should stop here.
# 9897 days have passed! Your final score is €0.00. Your script should stop here.
# 9898 days have passed! Your final score is €0.00. Your script should stop here.
# 9899 days have passed! Your final score is €0.00. Your script should stop here.
# 9900 days have passed! Your final score is €0.00. Your script should stop here.
# 9901 days have passed! Your final score is €0.00. Your script should stop here.
# 9902 days have passed! Your final score is €0.00. Your script should stop here.
# 9903 days have passed! Your final score is €0.00. Your script should stop here.
# 9904 days have passed! Your final score is €0.00. Your script should stop here.
# 9905 days have passed! Your final score is €0.00. Your script should stop here.
# 9906 days have passed! Your final score is €0.00. Your script should stop here.
# 9907 days have passed! Your final score is €0.00. Your script should stop here.
# 9908 days have passed! Your final score is €0.00. Your script should stop here.
# 9909 days have passed! Your final score is €0.00. Your script should stop here.
# 9910 days have passed! Your final score is €0.00. Your script should stop here.
# 9911 days have passed! Your final score is €0.00. Your script should stop here.
# 9912 days have passed! Your final score is €0.00. Your script should stop here.
# 9913 days have passed! Your final score is €0.00. Your script should stop here.
# 9914 days have passed! Your final score is €0.00. Your script should stop here.
# 9915 days have passed! Your final score is €0.00. Your script should stop here.
# 9916 days have passed! Your final score is €0.00. Your script should stop here.
# 9917 days have passed! Your final score is €0.00. Your script should stop here.
# 9918 days have passed! Your final score is €0.00. Your script should stop here.
# 9919 days have passed! Your final score is €0.00. Your script should stop here.
# 9920 days have passed! Your final score is €0.00. Your script should stop here.
# 9921 days have passed! Your final score is €0.00. Your script should stop here.
# 9922 days have passed! Your final score is €0.00. Your script should stop here.
# 9923 days have passed! Your final score is €0.00. Your script should stop here.
# 9924 days have passed! Your final score is €0.00. Your script should stop here.
# 9925 days have passed! Your final score is €0.00. Your script should stop here.
# 9926 days have passed! Your final score is €0.00. Your script should stop here.
# 9927 days have passed! Your final score is €0.00. Your script should stop here.
# 9928 days have passed! Your final score is €0.00. Your script should stop here.
# 9929 days have passed! Your final score is €0.00. Your script should stop here.
# 9930 days have passed! Your final score is €0.00. Your script should stop here.
# 9931 days have passed! Your final score is €0.00. Your script should stop here.
# 9932 days have passed! Your final score is €0.00. Your script should stop here.
# 9933 days have passed! Your final score is €0.00. Your script should stop here.
# 9934 days have passed! Your final score is €0.00. Your script should stop here.
# 9935 days have passed! Your final score is €0.00. Your script should stop here.
# 9936 days have passed! Your final score is €0.00. Your script should stop here.
# 9937 days have passed! Your final score is €0.00. Your script should stop here.
# 9938 days have passed! Your final score is €0.00. Your script should stop here.
# 9939 days have passed! Your final score is €0.00. Your script should stop here.
# 9940 days have passed! Your final score is €0.00. Your script should stop here.
# 9941 days have passed! Your final score is €0.00. Your script should stop here.
# 9942 days have passed! Your final score is €0.00. Your script should stop here.
# 9943 days have passed! Your final score is €0.00. Your script should stop here.
# 9944 days have passed! Your final score is €0.00. Your script should stop here.
# 9945 days have passed! Your final score is €0.00. Your script should stop here.
# 9946 days have passed! Your final score is €0.00. Your script should stop here.
# 9947 days have passed! Your final score is €0.00. Your script should stop here.
# 9948 days have passed! Your final score is €0.00. Your script should stop here.
# 9949 days have passed! Your final score is €0.00. Your script should stop here.
# 9950 days have passed! Your final score is €0.00. Your script should stop here.
# 9951 days have passed! Your final score is €0.00. Your script should stop here.
# 9952 days have passed! Your final score is €0.00. Your script should stop here.
# 9953 days have passed! Your final score is €0.00. Your script should stop here.
# 9954 days have passed! Your final score is €0.00. Your script should stop here.
# 9955 days have passed! Your final score is €0.00. Your script should stop here.
# 9956 days have passed! Your final score is €0.00. Your script should stop here.
# 9957 days have passed! Your final score is €0.00. Your script should stop here.
# 9958 days have passed! Your final score is €0.00. Your script should stop here.
# 9959 days have passed! Your final score is €0.00. Your script should stop here.
# 9960 days have passed! Your final score is €0.00. Your script should stop here.
# 9961 days have passed! Your final score is €0.00. Your script should stop here.
# 9962 days have passed! Your final score is €0.00. Your script should stop here.
# 9963 days have passed! Your final score is €0.00. Your script should stop here.
# 9964 days have passed! Your final score is €0.00. Your script should stop here.
# 9965 days have passed! Your final score is €0.00. Your script should stop here.
# 9966 days have passed! Your final score is €0.00. Your script should stop here.
# 9967 days have passed! Your final score is €0.00. Your script should stop here.
# 9968 days have passed! Your final score is €0.00. Your script should stop here.
# 9969 days have passed! Your final score is €0.00. Your script should stop here.
# 9970 days have passed! Your final score is €0.00. Your script should stop here.
# 9971 days have passed! Your final score is €0.00. Your script should stop here.
# 9972 days have passed! Your final score is €0.00. Your script should stop here.
# 9973 days have passed! Your final score is €0.00. Your script should stop here.
# 9974 days have passed! Your final score is €0.00. Your script should stop here.
# 9975 days have passed! Your final score is €0.00. Your script should stop here.
# 9976 days have passed! Your final score is €0.00. Your script should stop here.
# 9977 days have passed! Your final score is €0.00. Your script should stop here.
# 9978 days have passed! Your final score is €0.00. Your script should stop here.
# 9979 days have passed! Your final score is €0.00. Your script should stop here.
# 9980 days have passed! Your final score is €0.00. Your script should stop here.
# 9981 days have passed! Your final score is €0.00. Your script should stop here.
# 9982 days have passed! Your final score is €0.00. Your script should stop here.
# 9983 days have passed! Your final score is €0.00. Your script should stop here.
# 9984 days have passed! Your final score is €0.00. Your script should stop here.
# 9985 days have passed! Your final score is €0.00. Your script should stop here.
# 9986 days have passed! Your final score is €0.00. Your script should stop here.
# 9987 days have passed! Your final score is €0.00. Your script should stop here.
# 9988 days have passed! Your final score is €0.00. Your script should stop here.
# 9989 days have passed! Your final score is €0.00. Your script should stop here.
# 9990 days have passed! Your final score is €0.00. Your script should stop here.
# 9991 days have passed! Your final score is €0.00. Your script should stop here.
# 9992 days have passed! Your final score is €0.00. Your script should stop here.
# 9993 days have passed! Your final score is €0.00. Your script should stop here.
# 9994 days have passed! Your final score is €0.00. Your script should stop here.
# 9995 days have passed! Your final score is €0.00. Your script should stop here.
# 9996 days have passed! Your final score is €0.00. Your script should stop here.
# 9997 days have passed! Your final score is €0.00. Your script should stop here.
# 9998 days have passed! Your final score is €0.00. Your script should stop here.
